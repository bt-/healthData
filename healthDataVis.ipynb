# %% [markdown]
# # Table of Contents
#  <p>

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
#created random data dn exported to excel
#data = np.random.randint(1,high=10,size=900).reshape(100,9)
#df = pd.DataFrame(data, columns=['A','B','C','D','E','F','G','H','I'])
#df.to_csv("./randHealthGroups.csv")

# %%
df = pd.read_csv("./randHealthGroups.csv", index_col=0)

# %%
#dummy data for 100 people
#Methods A through I grouped each person into Groups 1-9
#groups 1-9 generated by pseudo random number generator
# Out:
#    A  B  C  D  E  F  G  H  I
# 0  3  4  5  2  8  8  1  2  6
# 1  9  7  5  1  2  4  3  9  2
# 2  1  2  8  7  5  6  6  3  5
# 3  8  6  2  8  1  1  3  3  1
# 4  8  4  4  6  7  2  7  6  3

# %%
#creates a new dataframe that provides the counts of people per Group for each method
valCounts = df.apply(pd.value_counts)
valCounts
# Out:
#     A   B   C   D   E   F   G   H   I
# 1  16   8  11  19  11  12   7  14   8
# 2  11  15  13   7  12  13  11   8  13
# 3  13   6  13  20  11  10  10   8  10
# 4   7  12  12   6   5   9  12   9  13
# 5  10   9   9   9   8  15  12   9  11
# 6  10  15  10  11  14  10  11   8  12
# 7  10  12   6  11  14   8  19  10  15
# 8  13   9  11  10  13  15  11  17   7
# 9  10  14  15   7  12   8   7  17  11

# %%
#this line can be used to sort the dataframe by each method
valCounts.sort_values('A', ascending=False)
# Out:
#     A   B   C   D   E   F   G   H   I
# 1  16   8  11  19  11  12   7  14   8
# 3  13   6  13  20  11  10  10   8  10
# 8  13   9  11  10  13  15  11  17   7
# 2  11  15  13   7  12  13  11   8  13
# 5  10   9   9   9   8  15  12   9  11
# 6  10  15  10  11  14  10  11   8  12
# 7  10  12   6  11  14   8  19  10  15
# 9  10  14  15   7  12   8   7  17  11
# 4   7  12  12   6   5   9  12   9  13

# %%
#provide summary statistics on the dataframe
valCounts.describe()
# Out:
#                A          B          C          D          E          F  \
# count   9.000000   9.000000   9.000000   9.000000   9.000000   9.000000
# mean   11.111111  11.111111  11.111111  11.111111  11.111111  11.111111
# std     2.571208   3.257470   2.619372   5.085382   2.934469   2.758824
# min     7.000000   6.000000   6.000000   6.000000   5.000000   8.000000
# 25%    10.000000   9.000000  10.000000   7.000000  11.000000   9.000000
# 50%    10.000000  12.000000  11.000000  10.000000  12.000000  10.000000
# 75%    13.000000  14.000000  13.000000  11.000000  13.000000  13.000000
# max    16.000000  15.000000  15.000000  20.000000  14.000000  15.000000
#
#                G          H          I
# count   9.000000   9.000000   9.000000
# mean   11.111111  11.111111  11.111111
# std     3.515837   3.822448   2.522124
# min     7.000000   8.000000   7.000000
# 25%    10.000000   8.000000  10.000000
# 50%    11.000000   9.000000  11.000000
# 75%    12.000000  14.000000  13.000000
# ...

# %%
df.plot.hist(subplots=True, figsize=(10,10), bins=9, sharey=True, layout=(3,3))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11b640048>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11dbf3eb8>]], dtype=object)

# %%
yticks = np.arange(1,10)
df['B'].plot(style='.', subplots=False, figsize=(10,4), ylim=(-0,9.5), yticks=yticks)

# %%
df.plot(style='.', subplots=False, figsize=(10,4), alpha=1, ylim=(-0,9.5), yticks=yticks)

# %%
df.plot(style='k.', subplots=False, figsize=(10,4), alpha=0.2, ylim=(-0,9.5), yticks=yticks)

# %%
df.ix[:,:'F'].plot(style='k.', subplots=False, figsize=(10,4), alpha=0.2, ylim=(-0,9.5), yticks=yticks)

# %%
df.plot(style='k.', subplots=True, figsize=(10,14), legend=True, ylim=(-0,9.5), yticks=yticks, sharey=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11fe2ac50>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x120049d68>], dtype=object)
